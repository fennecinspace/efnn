# %%
# mounting google drive to save data
# using efnn folder in side google drive as root folder for all project content
from google.colab import drive
drive.mount('/content/gdrive')
% cd "/content/gdrive/My Drive/efnn"
! mkdir -p ./dataset/exr
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/efnn

# %%
# downloading exr (hdr) files (104 samples)
! cd "/content/gdrive/My Drive/efnn/dataset/exr" && wget --show-progress --timeout 10 --tries 0 --continue -i ../dataset.txt
# Out:
# --2020-04-02 09:41:45--  http://www.cis.rit.edu/fairchild/HDRPS/EXRs/507.exr
# Resolving www.cis.rit.edu (www.cis.rit.edu)... 129.21.57.10
# Connecting to www.cis.rit.edu (www.cis.rit.edu)|129.21.57.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://rit-mcsl.org/fairchild//HDRPS/EXRs/507.exr [following]
# --2020-04-02 09:41:45--  http://rit-mcsl.org/fairchild//HDRPS/EXRs/507.exr
# Resolving rit-mcsl.org (rit-mcsl.org)... 50.63.112.1
# Connecting to rit-mcsl.org (rit-mcsl.org)|50.63.112.1|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2020-04-02 09:41:45--  http://www.cis.rit.edu/fairchild/HDRPS/EXRs/AhwahneeGreatLounge.exr
# Connecting to www.cis.rit.edu (www.cis.rit.edu)|129.21.57.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# ...

# %%
# ImageMagick v7 is used to extract .jpg exposures from the .exr hdr image. 
# unfortunaty the apt package manager installs version 6
# this manually downloads the source for version 7 then builds and installs it.
% cd /
! apt install openexr build-essential
! wget https://www.imagemagick.org/download/ImageMagick.tar.gz -O "ImageMagick.tar.gz"
! mkdir -p ImageMagick
! rm -rf ImageMagick/*
! tar -xf ImageMagick.tar.gz -C ImageMagick --strip-components=1 
% cd ImageMagick
! ls
! ./configure
! make
! make install
! ldconfig /user/local/lib
! magick -version
% cd "/content/gdrive/My Drive/efnn"
# Out:
# /
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# openexr is already the newest version (2.2.0-11.1ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# --2020-04-02 10:58:05--  https://www.imagemagick.org/download/ImageMagick.tar.gz
# Resolving www.imagemagick.org (www.imagemagick.org)... 198.72.81.86
# Connecting to www.imagemagick.org (www.imagemagick.org)|198.72.81.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14022928 (13M) [application/x-gzip]
# Saving to: ‘ImageMagick.tar.gz’
#
# ImageMagick.tar.gz  100%[===================>]  13.37M  9.50MB/s    in 1.4s
#
# 2020-04-02 10:58:07 (9.50 MB/s) - ‘ImageMagick.tar.gz’ saved [14022928/14022928]
#
# /ImageMagick
# aclocal.m4     filters		    LICENSE	   Makefile.in	   tests
# AUTHORS.txt    ImageMagick.spec.in  m4		   NEWS.txt	   utilities
# ...

# %%
# extracting evs from exr images
% cd "/content/gdrive/My Drive/efnn" 
! chmod +x extract_evs.sh
! chmod +x extract_allimages_evs.sh
! ./extract_allimages_evs.sh
# Out:
# /content/gdrive/My Drive/efnn
# Processing 507
# Processing AhwahneeGreatLounge
# Processing AirBellowsGap
# Processing AmikeusBeaverDamPM1
# Processing AmikeusBeaverDamPM2
# Processing ArtistPalette
# Processing BalancedRock
# Processing BandonSunset(1)
# Processing BandonSunset(2)
# Processing BarHarborPresunrise
# Processing BarHarborSunrise
# Processing BenJerrys
# Processing BigfootPass
# Processing BloomingGorse(1)
# Processing BloomingGorse(2)
# Processing CadesCove
# Processing CanadianFalls
# Processing CemeteryTree(1)
# Processing CemeteryTree(2)
# Processing DelicateArch
# Processing DelicateFlowers
# Processing DevilsBathtub
# Processing DevilsGolfCourse
# Processing DevilsTower
# Processing ElCapitan
# Processing Exploratorium(1)
# Processing Exploratorium(2)
# Processing Flamingo
# Processing FourCornersStorm
# Processing Frontier
# Processing GeneralGrant
# Processing GeneralSherman
# Processing GoldenGate(1)
# Processing GoldenGate(2)
# Processing HalfDomeSunset
# ...

# %%
# ! git clone https://github.com/logxseven/efnn
! pwd
! ls
# Out:
# /content/gdrive/My Drive/efnn
#  3rd.hdf5	    dataset		       ImageMagick-7.0.10-3
#  archive	    efnn		       ImageMagick.tar.gz
#  bgr_3rd.png	    extract_allimages_evs.sh   rgb_data.npy
#  bgr_model.hdf5     extract_evs.sh	       rgb_labels.npy
# 'Colab Notebooks'   ImageMagick-7.0.10-2
